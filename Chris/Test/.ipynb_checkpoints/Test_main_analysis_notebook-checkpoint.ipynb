# %%
# Import the function or the entire module
from helper_functions import analyze_data 

# OR import the module and call the function using the module prefix
# import helper_functions
# result_mean = helper_functions.analyze_data(my_data, "mean")

# %%
# 1. Define your data
my_data = [10, 20, 30, 40, 50]

# 2. Call the imported function
result_mean = analyze_data(my_data, analysis_type="mean")
result_sum = analyze_data(my_data, analysis_type="sum")

print(f"\nFinal Mean Result: {result_mean}")
print(f"Final Sum Result: {result_sum}")
# Out:
# Calculated the mean: 30.0
# Calculated the sum: 150
#
# Final Mean Result: 30.0
# Final Sum Result: 150

# %%
analyze_data??
# Out:
# Signature: analyze_data(data_list, analysis_type='mean')
# Docstring:
# Performs a simple analysis on a list of numbers.
#
# Args:
#     data_list (list): A list of numbers.
#     analysis_type (str): The type of analysis ('mean' or 'sum').
#
# Returns:
#     float: The result of the analysis.
# Source:
# # Save this code as helper_functions.py
#
# print("hey")
#
# def analyze_data(data_list, analysis_type="mean"):
#     """
#     Performs a simple analysis on a list of numbers.
#
#     Args:
#         data_list (list): A list of numbers.
#         analysis_type (str): The type of analysis ('mean' or 'sum').
#
#     Returns:
#         float: The result of the analysis.
#     """
#     if analysis_type == "mean":
#         if not data_list:
#             return 0
#         result = sum(data_list) / len(data_list)
#         print(f"Calculated the mean: {result}")
#         return result
#     elif analysis_type == "sum":
#         result = sum(data_list)
# ...
